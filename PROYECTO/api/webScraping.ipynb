# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.planetadelibros.com/libros-mas-vendidos"

# %%
html = requests.get(url)
soup = BeautifulSoup(html.text, "html.parser")

# %%
titulosLib = []

secciones=[]
datos= soup.find_all('div', class_='Libro_libro__hfCan')

for item in datos:
    titulos= item.find_all('p', class_='Libro_libro__titulo__y773j')
    for item in titulos:
        titulo=item.find('span')
        book= titulo.text.strip()
        titulosLib.append(book)

# %%
titulos= [item for item in titulosLib if item !="" and item !="New" and item != "RE-\nENTRY"]

# %%
for tema in datos:
    generos= tema.find_all('a', class_="LibroTematicaPrincipal_tematicaPrincipal__AwP6o")
    # if generos:
        # genero=

# %%
datos
# Out:
# [<div class="Libro_libro__hfCan hasTags"><a class="Libro_libro__link__7GkLx" href="https://www.planetadelibros.com/libro-y-a-ti-que-te-pica/377670" title="¿Y a ti qué te pica?"><div class="Libro_libro__portadaAspectRatioWrapper___BAr4" style="aspect-ratio:0.572737686139748"><div class="Libro_libro__portadaPositionWrapper__U_pr0"><button aria-label="Play" aria-pressed="false" class="AudioBookPlay_audiobook__ajlSR"><img alt="Play" height="45" src="/assets/images/icons/audiobook_play.svg" width="45"/></button><span class="Libro_ranking__aesQe">1<!-- --></span><div class="LibroPortada_portada__G2flk undefined"><div class="Tags_tags__0CsTW undefined"><span class="Tags_tag__vSPkg Tags_masVendido__mfWSl">Más vendido</span></div><picture class="Picture_picture__rEASX LibroPortada_portada__image__MXGhj"><img alt="Portada ¿Y a ti qué te pica?" height="265" loading="lazy" src="https://proassetspdlcom.cdnstatics2.com/usuaris/libros/thumbs/68bbe54e-47b3-43ed-ba18-077e8020c563/m_175_310/portada_y-
# ...

# %%
titulosLib
# Out:
# ['¿Y a ti qué te pica?',
#  'El Ángel de la Ciudad',
#  'La rebelión de los buenos',
#  'Delito',
#  'Púa',
#  'Donde todo brilla',
#  'Esperando al diluvio',
#  'El arte de ser nosotros',
#  'Hijos de la fábula',
#  'Historias de mujeres casadas',
#  'Hábitos atómicos',
#  'Cómo hacer que te pasen cosas buenas',
#  'Encuentra tu persona vitamina',
#  'Las 48 leyes del poder',
#  'Nuestro cuerpo',
#  'La revolución de la glucosa',
#  'Hábitos que te salvarán la vida',
#  'El retorno de la Derecha',
#  'Querido cerebro, ¿qué coño quieres de mí?',
#  'La encrucijada mundial',
#  'Destroza este diario. Ahora a todo color',
#  'Anna Kadabra 12. Brujos en pañales',
#  'Compas 9. Los Compas y el despertar de la momia',
#  'Las Ratitas 9. La cabaña embrujada',
#  'Los misterios de los Polo 1. El parque de atracciones encantado',
#  'Osito Tito. Un día en el cole',
#  'No te comas este libro',
#  'Marcus Pocus 1. Magia a domicilio',
#  'Los tres cerditos. Cuento con mecanismos',
# ...

# %%
book
# Out:
# '¿Y si lo probamos...?'

# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
ScrollNumber = 50
for i in range(1,ScrollNumber):
    titulosLib

# %%
titulosLib
# Out:
# ['¿Y a ti qué te pica?',
#  'El Ángel de la Ciudad',
#  'La rebelión de los buenos',
#  'Delito',
#  'Púa',
#  'Donde todo brilla',
#  'Esperando al diluvio',
#  'El arte de ser nosotros',
#  'Hijos de la fábula',
#  'Historias de mujeres casadas',
#  'Hábitos atómicos',
#  'Cómo hacer que te pasen cosas buenas',
#  'Encuentra tu persona vitamina',
#  'Las 48 leyes del poder',
#  'Nuestro cuerpo',
#  'La revolución de la glucosa',
#  'Hábitos que te salvarán la vida',
#  'El retorno de la Derecha',
#  'Querido cerebro, ¿qué coño quieres de mí?',
#  'La encrucijada mundial',
#  'Destroza este diario. Ahora a todo color',
#  'Anna Kadabra 12. Brujos en pañales',
#  'Compas 9. Los Compas y el despertar de la momia',
#  'Las Ratitas 9. La cabaña embrujada',
#  'Los misterios de los Polo 1. El parque de atracciones encantado',
#  'Osito Tito. Un día en el cole',
#  'No te comas este libro',
#  'Marcus Pocus 1. Magia a domicilio',
#  'Los tres cerditos. Cuento con mecanismos',
# ...
